# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !ls "/content/drive/My Drive/Colab Notebooks"
file_path = "/content/drive/My Drive/Colab Notebooks/all_text.txt"
# Out:
# 'Advanced BERTopic.ipynb'   BERTopic_topic_list.txt
#  all_text.txt		   'Copy of cataract_CNN_clf.ipynb'

# %%
with open(file_path, 'r', encoding='utf-8') as file:
        all_text = file.read()

# %%
text_list = all_text.split('+++')
text_list[:5]
# Out:
# ['Some people belive that the so called "face" on mars was created by life on mars. This is not the case. The face on Mars is a naturally occuring land form called a mesa. It was not created by aliens, and there is no consiracy to hide alien lifeforms on mars. There is no evidence that NASA has found that even suggests that this face was created by aliens.\n\nA mesa is a naturally occuring rock formation, that is found on Mars and Earth. This "face" on mars only looks like a face because humans tend to see faces wherever we look, humans are obviously extremely social, which is why our brain is designed to recognize faces.\n\nMany conspiracy theorists believe that NASA is hiding life on Mars from the rest of the world. These people would be very wrong. If NASA found life on Mars, then they would get millions of people\'s attention. NASA\'s budget would increase drasticly, which means that their workers would get paid more. There is no good reason that NASA would hide life on Mars from the rest of the world.\n\nSo, NASA is not hiding life on Mars from us, and they are not trying to trick us into thinking that the "face" on mars is just a mesa, because it actually is. NASA hiding life would be illogical, because if they found life on Mars, they would make a lot of money, and we all know that the people at NASA aren\'t illogical people.',
#  "Driverless cars are exaclty what you would expect them to be. Cars that will drive without a person actually behind the wheel controlling the actions of the vehicle. The idea of driverless cars going in to developement shows the amount of technological increase that the wolrd has made. The leader of this idea of driverless cars are the automobiles they call Google cars. The arduous task of creating safe driverless cars has not been fully mastered yet. The developement of these cars should be stopped immediately because there are too many hazardous and dangerous events that could occur.\n\nOne thing that the article mentions is that the driver will be alerted when they will need to take over the driving responsibilites of the car. This is such a dangerous thing because we all know that whenever humans get their attention drawn in on something interesting it is hard to draw their focus somewhere else. The article explains that companies are trying to implement vibrations when the car is in trouble. Their are some people out there who do not feel vibrations and therefore would not be able to take control of the car when needed. The article also states that companies are trying to put in-car entertainment into the car while it is being driven. This is just another thing that will distract the person who is supposed to be ready at all times to take over driving when asked to do so.\n\nAnother thing that can go wrong with these cars is any type of techological malfucntion. Every person with any kind of technological device has experienced some sort of error. Now imagine if your car has an error technologically and it takes the life of one your loved ones. The article talks about sensors around the car that read the surroundings of the car and that is what helps he car to drive without a true driver behind the wheel. Those sensors could have a malfunctions and be sensing something that is that even there and make a left turn into a 100 foot deep lake. The vibrations that cause the driver to be notified to drive could malfunction and now the driver has no way of knowing that the car is in trouble and now you, the driver, and the rest of your passengers are being buried in your local cemetery.\n\nOne last thing that the article mentions is negative about the developement of driverless cars is who to blame for the wreck if there were possibly some sort of technological malfunciton or even some sort of human error when taking over the driving aspect. Should the manufacturer of the car be blamed or should it be the driver? No one knows because there is so many different factors that attribute to who to assign the blame to. Some of what will have to be made is a judgement call. When it comes to insurance and having to pay for any damages you do not want someone to have to make some sort of judgement call. What if that judgement call that was made was the wrong call? Now there are going to be even more lawsuits today in our courts than there already are. This problem alone will just lead to many more issues today in the world that should not have to be dealt with.\n\nWith all these things that could possibly go wrong with these driverless cars there is no way that the developement of them should continue any further. In today's society if something bad COULD happen or something COULD go wrong, it WILL happen, and it WILL go wrong. There are just way too many safety hazards that come along with these driverless cars. Becuase of all of these problems that arise with the cars it is just a gargantuan risk to implement these cars into our lifestyles. ",
#  "I think that students would benefit from learning at home,because they wont have\xa0to change and get up early in the morning to shower and do there hair. taking only classes helps them because at there house they'll be pay more attention. they will be comfortable at home.\n\nThe hardest part of school is getting ready. you wake up go brush your teeth and go to your closet and look at your cloths. after you think you picked a outfit u go look in the mirror and youll either not like it or you look and see a stain. Then you'll have to change. with the online classes you can wear anything and stay home and you wont need to stress about what to wear.\n\nmost students usually take showers before school. they either take it before they sleep or when they wake up. some students do both to smell good. that causes them do miss the bus and effects on there lesson time cause they come late to school. when u have online classes u wont need to miss lessons cause you can get everything set up and go take a shower and when u get out your ready to go.\n\nwhen your home your\xa0comfortable and you pay attention. it gives then an advantage to be smarter and even pass there classmates on class work. public schools are difficult even if you try. some teacher dont know how to teach it in then way that students understand it. that causes students to fail and they may repeat the class.\xa0   \xa0 \xa0\xa0   \xa0 \xa0"]

# %%
len(text_list)
# Out:
# 15595

# %%
# !pip install bertopic
# Out:
# Requirement already satisfied: bertopic in /usr/local/lib/python3.10/dist-packages (0.15.0)
# Requirement already satisfied: numpy>=1.20.0 in /usr/local/lib/python3.10/dist-packages (from bertopic) (1.23.5)
# Requirement already satisfied: hdbscan>=0.8.29 in /usr/local/lib/python3.10/dist-packages (from bertopic) (0.8.33)
# Requirement already satisfied: umap-learn>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from bertopic) (0.5.5)
# Requirement already satisfied: pandas>=1.1.5 in /usr/local/lib/python3.10/dist-packages (from bertopic) (1.5.3)
# Requirement already satisfied: scikit-learn>=0.22.2.post1 in /usr/local/lib/python3.10/dist-packages (from bertopic) (1.2.2)
# Requirement already satisfied: tqdm>=4.41.1 in /usr/local/lib/python3.10/dist-packages (from bertopic) (4.66.1)
# Requirement already satisfied: sentence-transformers>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from bertopic) (2.2.2)
# Requirement already satisfied: plotly>=4.7.0 in /usr/local/lib/python3.10/dist-packages (from bertopic) (5.15.0)
# Requirement already satisfied: cython<3,>=0.27 in /usr/local/lib/python3.10/dist-packages (from hdbscan>=0.8.29->bertopic) (0.29.36)
# Requirement already satisfied: scipy>=1.0 in /usr/local/lib/python3.10/dist-packages (from hdbscan>=0.8.29->bertopic) (1.11.3)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.10/dist-packages (from hdbscan>=0.8.29->bertopic) (1.3.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.5->bertopic) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.5->bertopic) (2023.3.post1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly>=4.7.0->bertopic) (8.2.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from plotly>=4.7.0->bertopic) (23.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.22.2.post1->bertopic) (3.2.0)
# Requirement already satisfied: transformers<5.0.0,>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.4.1->bertopic) (4.35.2)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.4.1->bertopic) (2.1.0+cu118)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.4.1->bertopic) (0.16.0+cu118)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.4.1->bertopic) (3.8.1)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.4.1->bertopic) (0.1.99)
# Requirement already satisfied: huggingface-hub>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.4.1->bertopic) (0.19.4)
# Requirement already satisfied: numba>=0.51.2 in /usr/local/lib/python3.10/dist-packages (from umap-learn>=0.5.0->bertopic) (0.58.1)
# Requirement already satisfied: pynndescent>=0.5 in /usr/local/lib/python3.10/dist-packages (from umap-learn>=0.5.0->bertopic) (0.5.11)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (2023.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (2.31.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (4.5.0)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.51.2->umap-learn>=0.5.0->bertopic) (0.41.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas>=1.1.5->bertopic) (1.16.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (3.1.2)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (2.1.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic) (2023.6.3)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic) (0.15.0)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic) (0.4.0)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->sentence-transformers>=0.4.1->bertopic) (8.1.7)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision->sentence-transformers>=0.4.1->bertopic) (9.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (2023.7.22)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (1.3.0)

# %%
import nltk.corpus

# %%
from sentence_transformers import SentenceTransformer
from umap import UMAP
from hdbscan import HDBSCAN

#Transformer...384-dimensional sentence embedding
embedding_model = SentenceTransformer('all-MiniLM-L6-v2')

#Dimensionality reduction - compresses into 3 dimensions (default 2).
#UMAP attempts to preserves distances to kth nearest neightbor while lowering dimension
umap_model = UMAP(n_neighbors= 10,
                  n_components = 3,
                  min_dist = 1)

#HDBSCAN(hierarachical, density-based method) clusters lower dimensional vectors
hdbscan_model = HDBSCAN(min_cluster_size = 10,
                 min_samples = 5,
                 gen_min_span_tree = True,
                 prediction_data = True)

# %%
from sklearn.feature_extraction.text import CountVectorizer
from nltk.corpus import stopwords
nltk.download('stopwords')

stopwords = list(stopwords.words('english'))

#This removes the stopwords and vectorizes with
vectorizer_model = CountVectorizer(ngram_range=(1, 1), stop_words=stopwords)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
from bertopic import BERTopic

model = BERTopic(
    umap_model=umap_model,
    hdbscan_model=hdbscan_model,
    embedding_model=embedding_model,
    vectorizer_model=vectorizer_model,
    top_n_words=5, #number of words per topic
    language='english',
    calculate_probabilities=True,
    verbose=True
)

topics, probs = model.fit_transform(text_list)
# Out:
# Batches:   0%|          | 0/488 [00:00<?, ?it/s]
# 2023-11-22 22:24:39,096 - BERTopic - Transformed documents to Embeddings
# 2023-11-22 22:24:53,487 - BERTopic - Reduced dimensionality
# 2023-11-22 22:24:55,392 - BERTopic - Clustered reduced embeddings

# %%
model.get_topics()
# Out:
# {-1: [('generic_name', 0.17564663823074853),
#   ('team', 0.10413410231351307),
#   ('participate', 0.09861484177547639),
#   ('activities', 0.06634945505237057),
#   ('school', 0.055883060433921626)],
#  0: [('electoral', 0.11353156206756654),
#   ('vote', 0.10136076037482966),
#   ('college', 0.09726761779370809),
#   ('president', 0.07912646299620354),
#   ('electors', 0.05793086137152826)],
#  1: [('activities', 0.06318415426920167),
#   ('school', 0.060605266522912545),
#   ('students', 0.057389412804660124),
#   ('extracurricular', 0.05610689325070386),
#   ('sports', 0.056059640941108366)],
#  2: [('advice', 0.09857189875524897),
#   ('people', 0.06148963466833003),
#   ('ask', 0.05709284293306092),
#   ('multiple', 0.054486579822594056),
#   ('opinions', 0.05441186696731158)],
#  3: [('students', 0.07176651815160463),
#   ('online', 0.06885781833667295),
#   ('school', 0.061033056547639374),
#   ('classes', 0.06039170159021019),
#   ('home', 0.05711554509357248)],
#  4: [('cars', 0.11381974108204956),
#   ('driverless', 0.10278369213098826),
#   ('car', 0.09012840809569074),
#   ('driver', 0.05031788337460379),
#   ('would', 0.038245340545483744)],
#  5: [('emotions', 0.06433625572524954),
#   ('technology', 0.060919382601569844),
#   ('facial', 0.06007047904327865),
#   ('computer', 0.05105142443110729),
#   ('could', 0.0409972160804011)],
#  6: [('car', 0.07838997611571213),
#   ('cars', 0.06612992604664841),
#   ('usage', 0.04132190222256367),
#   ('pollution', 0.03741028974126443),
#   ('air', 0.03639141637211378)],
#  7: [('venus', 0.198448246936421),
#   ('planet', 0.08530038568777294),
#   ('earth', 0.07801098722036036),
#   ('author', 0.07790529188194685),
#   ('surface', 0.038376847153780695)],
#  8: [('summer', 0.10268045615976823),
#   ('project', 0.09722322062018698),
#   ('projects', 0.09550685586724782),
#   ('students', 0.08584780022028071),
#   ('designed', 0.06757753036168798)],
#  9: [('phones', 0.13461117774039327),
#   ('cell', 0.10265678510404512),
#   ('phone', 0.07159538992728647),
#   ('policy', 0.07062638564514821),
#   ('school', 0.06886329990555222)],
#  10: [('face', 0.1467826112907544),
#   ('mars', 0.12421280851217162),
#   ('landform', 0.07911857270394572),
#   ('aliens', 0.07741781338342445),
#   ('natural', 0.06415328808296887)],
#  11: [('community', 0.19546173095650773),
#   ('service', 0.15510724844542148),
#   ('help', 0.05254141096186374),
#   ('think', 0.04028872252113893),
#   ('students', 0.038460730270866585)],
#  12: [('driving', 0.13285682040668162),
#   ('phone', 0.09993270498726686),
#   ('phones', 0.06793326267265637),
#   ('cell', 0.06393065160197173),
#   ('texting', 0.058607029749079935)],
#  13: [('seagoing', 0.11070920356223603),
#   ('luke', 0.08160130458691472),
#   ('animals', 0.07663737138564614),
#   ('cowboys', 0.07314454798084365),
#   ('cowboy', 0.06560035604349518)]}

# %%
info_df = model.get_topic_info()
info_df
# Out:
#     Topic  Count                                          Name  \
# 0      -1      2   -1_generic_name_team_participate_activities
# 1       0   1820            0_electoral_vote_college_president
# 2       1   1649  1_activities_school_students_extracurricular
# 3       2   1544                  2_advice_people_ask_multiple
# 4       3   1499              3_students_online_school_classes
# 5       4   1385                  4_cars_driverless_car_driver
# 6       5   1102         5_emotions_technology_facial_computer
# 7       6    982                    6_car_cars_usage_pollution
# 8       7    928                   7_venus_planet_earth_author
# 9       8    873            8_summer_project_projects_students
# 10      9    830                    9_phones_cell_phone_policy
# 11     10    820                  10_face_mars_landform_aliens
# 12     11    768               11_community_service_help_think
# 13     12    706                  12_driving_phone_phones_cell
# 14     13    687              13_seagoing_luke_animals_cowboys
#
#                                        Representation  \
# 0   [generic_name, team, participate, activities, ...
# 1     [electoral, vote, college, president, electors]
# 2   [activities, school, students, extracurricular...
# 3           [advice, people, ask, multiple, opinions]
# 4           [students, online, school, classes, home]
# 5              [cars, driverless, car, driver, would]
# 6     [emotions, technology, facial, computer, could]
# 7                  [car, cars, usage, pollution, air]
# 8             [venus, planet, earth, author, surface]
# 9     [summer, project, projects, students, designed]
# 10              [phones, cell, phone, policy, school]
# 11            [face, mars, landform, aliens, natural]
# 12        [community, service, help, think, students]
# 13            [driving, phone, phones, cell, texting]
# 14         [seagoing, luke, animals, cowboys, cowboy]
#
#                                   Representative_Docs
# 0   [Boom! Generic_Name kicks the soccer ball as h...
# 1   [Electoral College is where we pick our state ...
# 2   [Dear, Principle\n\nI disagree with the new sc...
# 3   [Why do people ask multiple people for their o...
# 4   [The idea of online school sounds like a dream...
# 5   [Driverless cars could have a very postive imp...
# 6   [The Facial Action Coding System is a new soft...
# 7   [Ever since cars were invented, they have wide...
# 8   [Venus is the closest planet to Earth. The pla...
# 9   [Summer break is all about fun and hanging out...
# 10  [Dear Principal,\n\nI believe that policy 1 is...
# 11  [The Landform that Looks like a Face\n\nOn Ear...
# 12  [Dear Principal,\n\nHelping out the community ...
# 13  [Phones & Driving\n\nShould people use their p...
# 14  [The Seagoing Cowboys is a great program, but ...

# %%
model.topics_[:10]
# Out:
# [10, 4, 1, 6, 3, 13, 7, 3, 6, 12]

# %%
clusters = model.topics_
topic_str = ''

for cluster in clusters:
  topic = info_df.iloc[cluster + 1].Representation
  for word in topic:
    topic_str += word + ' '
  topic_str += '+++'

topic_str[:200]
# Out:
# 'face mars landform aliens natural +++cars driverless car driver would +++activities school students extracurricular sports +++car cars usage pollution air +++students online school classes home +++sea'

# %%
clusters = model.topics_
rep_list = []
for cluster in clusters:
  rep = info_df.iloc[cluster].Representation
  rep_list.append(rep)

rep_list
# Out:
# [['phones', 'cell', 'phone', 'policy', 'school'],
#  ['students', 'online', 'school', 'classes', 'home'],
#  ['electoral', 'vote', 'college', 'president', 'electors'],
#  ['emotions', 'technology', 'facial', 'computer', 'could'],
#  ['advice', 'people', 'ask', 'multiple', 'opinions'],
#  ['driving', 'phone', 'phones', 'cell', 'texting'],
#  ['car', 'cars', 'usage', 'pollution', 'air'],
#  ['advice', 'people', 'ask', 'multiple', 'opinions'],
#  ['emotions', 'technology', 'facial', 'computer', 'could'],
#  ['community', 'service', 'help', 'think', 'students'],
#  ['electoral', 'vote', 'college', 'president', 'electors'],
#  ['electoral', 'vote', 'college', 'president', 'electors'],
#  ['phones', 'cell', 'phone', 'policy', 'school'],
#  ['generic_name', 'team', 'participate', 'activities', 'school'],
#  ['electoral', 'vote', 'college', 'president', 'electors'],
#  ['electoral', 'vote', 'college', 'president', 'electors'],
#  ['face', 'mars', 'landform', 'aliens', 'natural'],
#  ['emotions', 'technology', 'facial', 'computer', 'could'],
#  ['face', 'mars', 'landform', 'aliens', 'natural'],
#  ['phones', 'cell', 'phone', 'policy', 'school'],
#  ['students', 'online', 'school', 'classes', 'home'],
#  ['advice', 'people', 'ask', 'multiple', 'opinions'],
#  ['generic_name', 'team', 'participate', 'activities', 'school'],
#  ['electoral', 'vote', 'college', 'president', 'electors'],
#  ['community', 'service', 'help', 'think', 'students'],
#  ['cars', 'driverless', 'car', 'driver', 'would'],
#  ['phones', 'cell', 'phone', 'policy', 'school'],
#  ['activities', 'school', 'students', 'extracurricular', 'sports'],
#  ['advice', 'people', 'ask', 'multiple', 'opinions'],
#  ['community', 'service', 'help', 'think', 'students'],
#  ['summer', 'project', 'projects', 'students', 'designed'],
#  ['summer', 'project', 'projects', 'students', 'designed'],
#  ['electoral', 'vote', 'college', 'president', 'electors'],
#  ['students', 'online', 'school', 'classes', 'home'],
#  ['generic_name', 'team', 'participate', 'activities', 'school'],
#  ['venus', 'planet', 'earth', 'author', 'surface'],
#  ['summer', 'project', 'projects', 'students', 'designed'],
#  ['emotions', 'technology', 'facial', 'computer', 'could'],
#  ['generic_name', 'team', 'participate', 'activities', 'school'],
#  ['community', 'service', 'help', 'think', 'students'],
#  ['students', 'online', 'school', 'classes', 'home'],
#  ['activities', 'school', 'students', 'extracurricular', 'sports'],
#  ['activities', 'school', 'students', 'extracurricular', 'sports'],
#  ['generic_name', 'team', 'participate', 'activities', 'school'],
#  ['generic_name', 'team', 'participate', 'activities', 'school'],
#  ['cars', 'driverless', 'car', 'driver', 'would'],
#  ['cars', 'driverless', 'car', 'driver', 'would'],
#  ['car', 'cars', 'usage', 'pollution', 'air'],
#  ['students', 'online', 'school', 'classes', 'home'],
#  ['activities', 'school', 'students', 'extracurricular', 'sports'],
#  ['emotions', 'technology', 'facial', 'computer', 'could'],
#  ['cars', 'driverless', 'car', 'driver', 'would'],
#  ['students', 'online', 'school', 'classes', 'home'],
#  ['face', 'mars', 'landform', 'aliens', 'natural'],
#  ['activities', 'school', 'students', 'extracurricular', 'sports'],
#  ['face', 'mars', 'landform', 'aliens', 'natural'],
#  ['car', 'cars', 'usage', 'pollution', 'air'],
#  ['driving', 'phone', 'phones', 'cell', 'texting'],
#  ['generic_name', 'team', 'participate', 'activities', 'school'],
#  ['driving', 'phone', 'phones', 'cell', 'texting'],
#  ['community', 'service', 'help', 'think', 'students'],
#  ['electoral', 'vote', 'college', 'president', 'electors'],
#  ['emotions', 'technology', 'facial', 'computer', 'could'],
#  ['face', 'mars', 'landform', 'aliens', 'natural'],
#  ['cars', 'driverless', 'car', 'driver', 'would'],
#  ['activities', 'school', 'students', 'extracurricular', 'sports'],
#  ['generic_name', 'team', 'participate', 'activities', 'school'],
#  ['phones', 'cell', 'phone', 'policy', 'school'],
#  ['car', 'cars', 'usage', 'pollution', 'air'],
#  ['advice', 'people', 'ask', 'multiple', 'opinions'],
#  ['electoral', 'vote', 'college', 'president', 'electors'],
#  ['electoral', 'vote', 'college', 'president', 'electors'],
#  ['venus', 'planet', 'earth', 'author', 'surface'],
#  ['cars', 'driverless', 'car', 'driver', 'would'],
#  ['car', 'cars', 'usage', 'pollution', 'air'],
#  ['students', 'online', 'school', 'classes', 'home'],
#  ['cars', 'driverless', 'car', 'driver', 'would'],
#  ['community', 'service', 'help', 'think', 'students'],
#  ['phones', 'cell', 'phone', 'policy', 'school'],
#  ['emotions', 'technology', 'facial', 'computer', 'could'],
#  ['electoral', 'vote', 'college', 'president', 'electors'],
#  ['students', 'online', 'school', 'classes', 'home'],
#  ['generic_name', 'team', 'participate', 'activities', 'school'],
#  ['electoral', 'vote', 'college', 'president', 'electors'],
#  ['face', 'mars', 'landform', 'aliens', 'natural'],
#  ['electoral', 'vote', 'college', 'president', 'electors'],
#  ['activities', 'school', 'students', 'extracurricular', 'sports'],
#  ['community', 'service', 'help', 'think', 'students'],
#  ['generic_name', 'team', 'participate', 'activities', 'school'],
#  ['generic_name', 'team', 'participate', 'activities', 'school'],
#  ['activities', 'school', 'students', 'extracurricular', 'sports'],
#  ['advice', 'people', 'ask', 'multiple', 'opinions'],
#  ['generic_name', 'team', 'participate', 'activities', 'school'],
#  ['car', 'cars', 'usage', 'pollution', 'air'],
#  ['summer', 'project', 'projects', 'students', 'designed'],
#  ['community', 'service', 'help', 'think', 'students'],
#  ['emotions', 'technology', 'facial', 'computer', 'could'],
#  ['students', 'online', 'school', 'classes', 'home'],
#  ['students', 'online', 'school', 'classes', 'home'],
#  ['advice', 'people', 'ask', 'multiple', 'opinions'],
#  ['electoral', 'vote', 'college', 'president', 'electors'],
#  ['cars', 'driverless', 'car', 'driver', 'would'],
#  ['face', 'mars', 'landform', 'aliens', 'natural'],
#  ['students', 'online', 'school', 'classes', 'home'],
#  ['advice', 'people', 'ask', 'multiple', 'opinions'],
#  ['face', 'mars', 'landform', 'aliens', 'natural'],
#  ['electoral', 'vote', 'college', 'president', 'electors'],
#  ['electoral', 'vote', 'college', 'president', 'electors'],
#  ['electoral', 'vote', 'college', 'president', 'electors'],
#  ['driving', 'phone', 'phones', 'cell', 'texting'],
#  ['car', 'cars', 'usage', 'pollution', 'air'],
#  ['students', 'online', 'school', 'classes', 'home'],
#  ['summer', 'project', 'projects', 'students', 'designed'],
#  ['cars', 'driverless', 'car', 'driver', 'would'],
#  ['emotions', 'technology', 'facial', 'computer', 'could'],
#  ['venus', 'planet', 'earth', 'author', 'surface'],
#  ['emotions', 'technology', 'facial', 'computer', 'could'],
#  ['face', 'mars', 'landform', 'aliens', 'natural'],
#  ['generic_name', 'team', 'participate', 'activities', 'school'],
#  ['students', 'online', 'school', 'classes', 'home'],
#  ['cars', 'driverless', 'car', 'driver', 'would'],
#  ['advice', 'people', 'ask', 'multiple', 'opinions'],
#  ['cars', 'driverless', 'car', 'driver', 'would'],
#  ['advice', 'people', 'ask', 'multiple', 'opinions'],
#  ['driving', 'phone', 'phones', 'cell', 'texting'],
#  ['advice', 'people', 'ask', 'multiple', 'opinions'],
#  ['emotions', 'technology', 'facial', 'computer', 'could'],
#  ['summer', 'project', 'projects', 'students', 'designed'],
#  ['electoral', 'vote', 'college', 'president', 'electors'],
#  ['generic_name', 'team', 'participate', 'activities', 'school'],
#  ['advice', 'people', 'ask', 'multiple', 'opinions'],
#  ['activities', 'school', 'students', 'extracurricular', 'sports'],
#  ['venus', 'planet', 'earth', 'author', 'surface'],
#  ['car', 'cars', 'usage', 'pollution', 'air'],
#  ['electoral', 'vote', 'college', 'president', 'electors'],
#  ['electoral', 'vote', 'college', 'president', 'electors'],
#  ['students', 'online', 'school', 'classes', 'home'],
#  ['cars', 'driverless', 'car', 'driver', 'would'],
#  ['emotions', 'technology', 'facial', 'computer', 'could'],
#  ['phones', 'cell', 'phone', 'policy', 'school'],
#  ['community', 'service', 'help', 'think', 'students'],
#  ['activities', 'school', 'students', 'extracurricular', 'sports'],
#  ['students', 'online', 'school', 'classes', 'home'],
#  ['cars', 'driverless', 'car', 'driver', 'would'],
#  ['driving', 'phone', 'phones', 'cell', 'texting'],
#  ['cars', 'driverless', 'car', 'driver', 'would'],
#  ['car', 'cars', 'usage', 'pollution', 'air'],
#  ['electoral', 'vote', 'college', 'president', 'electors'],
#  ['driving', 'phone', 'phones', 'cell', 'texting'],
#  ['activities', 'school', 'students', 'extracurricular', 'sports'],
#  ['summer', 'project', 'projects', 'students', 'designed'],
#  ['community', 'service', 'help', 'think', 'students'],
#  ['emotions', 'technology', 'facial', 'computer', 'could'],
#  ['cars', 'driverless', 'car', 'driver', 'would'],
#  ['students', 'online', 'school', 'classes', 'home'],
#  ['driving', 'phone', 'phones', 'cell', 'texting'],
#  ['phones', 'cell', 'phone', 'policy', 'school'],
#  ['community', 'service', 'help', 'think', 'students'],
#  ['phones', 'cell', 'phone', 'policy', 'school'],
#  ['advice', 'people', 'ask', 'multiple', 'opinions'],
#  ['car', 'cars', 'usage', 'pollution', 'air'],
#  ['students', 'online', 'school', 'classes', 'home'],
#  ['community', 'service', 'help', 'think', 'students'],
#  ['car', 'cars', 'usage', 'pollution', 'air'],
#  ['summer', 'project', 'projects', 'students', 'designed'],
#  ['students', 'online', 'school', 'classes', 'home'],
#  ['venus', 'planet', 'earth', 'author', 'surface'],
#  ['community', 'service', 'help', 'think', 'students'],
#  ['face', 'mars', 'landform', 'aliens', 'natural'],
#  ['activities', 'school', 'students', 'extracurricular', 'sports'],
#  ['electoral', 'vote', 'college', 'president', 'electors'],
#  ['advice', 'people', 'ask', 'multiple', 'opinions'],
#  ['generic_name', 'team', 'participate', 'activities', 'school'],
#  ['electoral', 'vote', 'college', 'president', 'electors'],
#  ['advice', 'people', 'ask', 'multiple', 'opinions'],
#  ['students', 'online', 'school', 'classes', 'home'],
#  ['cars', 'driverless', 'car', 'driver', 'would'],
#  ['advice', 'people', 'ask', 'multiple', 'opinions'],
#  ['cars', 'driverless', 'car', 'driver', 'would'],
#  ['generic_name', 'team', 'participate', 'activities', 'school'],
#  ['phones', 'cell', 'phone', 'policy', 'school'],
#  ['advice', 'people', 'ask', 'multiple', 'opinions'],
#  ['students', 'online', 'school', 'classes', 'home'],
#  ['community', 'service', 'help', 'think', 'students'],
#  ['summer', 'project', 'projects', 'students', 'designed'],
#  ['phones', 'cell', 'phone', 'policy', 'school'],
#  ['phones', 'cell', 'phone', 'policy', 'school'],
#  ['generic_name', 'team', 'participate', 'activities', 'school'],
#  ['students', 'online', 'school', 'classes', 'home'],
#  ['face', 'mars', 'landform', 'aliens', 'natural'],
#  ['community', 'service', 'help', 'think', 'students'],
#  ['emotions', 'technology', 'facial', 'computer', 'could'],
#  ['activities', 'school', 'students', 'extracurricular', 'sports'],
#  ['generic_name', 'team', 'participate', 'activities', 'school'],
#  ['car', 'cars', 'usage', 'pollution', 'air'],
#  ['advice', 'people', 'ask', 'multiple', 'opinions'],
#  ['car', 'cars', 'usage', 'pollution', 'air'],
#  ['generic_name', 'team', 'participate', 'activities', 'school'],
#  ['phones', 'cell', 'phone', 'policy', 'school'],
#  ['cars', 'driverless', 'car', 'driver', 'would'],
#  ['students', 'online', 'school', 'classes', 'home'],
#  ['cars', 'driverless', 'car', 'driver', 'would'],
#  ['students', 'online', 'school', 'classes', 'home'],
#  ['electoral', 'vote', 'college', 'president', 'electors'],
#  ['students', 'online', 'school', 'classes', 'home'],
#  ['activities', 'school', 'students', 'extracurricular', 'sports'],
#  ['electoral', 'vote', 'college', 'president', 'electors'],
#  ['driving', 'phone', 'phones', 'cell', 'texting'],
#  ['students', 'online', 'school', 'classes', 'home'],
#  ['advice', 'people', 'ask', 'multiple', 'opinions'],
#  ['activities', 'school', 'students', 'extracurricular', 'sports'],
#  ['advice', 'people', 'ask', 'multiple', 'opinions'],
#  ['summer', 'project', 'projects', 'students', 'designed'],
#  ['emotions', 'technology', 'facial', 'computer', 'could'],
#  ['generic_name', 'team', 'participate', 'activities', 'school'],
#  ['generic_name', 'team', 'participate', 'activities', 'school'],
#  ['venus', 'planet', 'earth', 'author', 'surface'],
#  ['electoral', 'vote', 'college', 'president', 'electors'],
#  ['advice', 'people', 'ask', 'multiple', 'opinions'],
#  ['advice', 'people', 'ask', 'multiple', 'opinions'],
#  ['face', 'mars', 'landform', 'aliens', 'natural'],
#  ['students', 'online', 'school', 'classes', 'home'],
#  ['activities', 'school', 'students', 'extracurricular', 'sports'],
#  ['students', 'online', 'school', 'classes', 'home'],
#  ['electoral', 'vote', 'college', 'president', 'electors'],
#  ['generic_name', 'team', 'participate', 'activities', 'school'],
#  ['face', 'mars', 'landform', 'aliens', 'natural'],
#  ['electoral', 'vote', 'college', 'president', 'electors'],
#  ['students', 'online', 'school', 'classes', 'home'],
#  ['generic_name', 'team', 'participate', 'activities', 'school'],
#  ['driving', 'phone', 'phones', 'cell', 'texting'],
#  ['emotions', 'technology', 'facial', 'computer', 'could'],
#  ['driving', 'phone', 'phones', 'cell', 'texting'],
#  ['activities', 'school', 'students', 'extracurricular', 'sports'],
#  ['car', 'cars', 'usage', 'pollution', 'air'],
#  ['cars', 'driverless', 'car', 'driver', 'would'],
#  ['face', 'mars', 'landform', 'aliens', 'natural'],
#  ['community', 'service', 'help', 'think', 'students'],
#  ['car', 'cars', 'usage', 'pollution', 'air'],
#  ['students', 'online', 'school', 'classes', 'home'],
#  ['generic_name', 'team', 'participate', 'activities', 'school'],
#  ['activities', 'school', 'students', 'extracurricular', 'sports'],
#  ['community', 'service', 'help', 'think', 'students'],
#  ['advice', 'people', 'ask', 'multiple', 'opinions'],
#  ['generic_name', 'team', 'participate', 'activities', 'school'],
#  ['summer', 'project', 'projects', 'students', 'designed'],
#  ['venus', 'planet', 'earth', 'author', 'surface'],
#  ['emotions', 'technology', 'facial', 'computer', 'could'],
#  ['summer', 'project', 'projects', 'students', 'designed'],
#  ['electoral', 'vote', 'college', 'president', 'electors'],
#  ['advice', 'people', 'ask', 'multiple', 'opinions'],
#  ['generic_name', 'team', 'participate', 'activities', 'school'],
#  ['advice', 'people', 'ask', 'multiple', 'opinions'],
#  ['students', 'online', 'school', 'classes', 'home'],
#  ['activities', 'school', 'students', 'extracurricular', 'sports'],
#  ['face', 'mars', 'landform', 'aliens', 'natural'],
#  ['emotions', 'technology', 'facial', 'computer', 'could'],
#  ['students', 'online', 'school', 'classes', 'home'],
#  ['activities', 'school', 'students', 'extracurricular', 'sports'],
#  ['students', 'online', 'school', 'classes', 'home'],
#  ['community', 'service', 'help', 'think', 'students'],
#  ['cars', 'driverless', 'car', 'driver', 'would'],
#  ['advice', 'people', 'ask', 'multiple', 'opinions'],
#  ['activities', 'school', 'students', 'extracurricular', 'sports'],
#  ['emotions', 'technology', 'facial', 'computer', 'could'],
#  ['activities', 'school', 'students', 'extracurricular', 'sports'],
#  ['advice', 'people', 'ask', 'multiple', 'opinions'],
#  ['phones', 'cell', 'phone', 'policy', 'school'],
#  ['generic_name', 'team', 'participate', 'activities', 'school'],
#  ['generic_name', 'team', 'participate', 'activities', 'school'],
#  ['electoral', 'vote', 'college', 'president', 'electors'],
#  ['activities', 'school', 'students', 'extracurricular', 'sports'],
#  ['cars', 'driverless', 'car', 'driver', 'would'],
#  ['activities', 'school', 'students', 'extracurricular', 'sports'],
#  ['advice', 'people', 'ask', 'multiple', 'opinions'],
#  ['venus', 'planet', 'earth', 'author', 'surface'],
#  ['electoral', 'vote', 'college', 'president', 'electors'],
#  ['activities', 'school', 'students', 'extracurricular', 'sports'],
#  ['car', 'cars', 'usage', 'pollution', 'air'],
#  ['face', 'mars', 'landform', 'aliens', 'natural'],
#  ['car', 'cars', 'usage', 'pollution', 'air'],
#  ['activities', 'school', 'students', 'extracurricular', 'sports'],
#  ['advice', 'people', 'ask', 'multiple', 'opinions'],
#  ['advice', 'people', 'ask', 'multiple', 'opinions'],
#  ['electoral', 'vote', 'college', 'president', 'electors'],
#  ['generic_name', 'team', 'participate', 'activities', 'school'],
#  ['driving', 'phone', 'phones', 'cell', 'texting'],
#  ['activities', 'school', 'students', 'extracurricular', 'sports'],
#  ['venus', 'planet', 'earth', 'author', 'surface'],
#  ['cars', 'driverless', 'car', 'driver', 'would'],
#  ['activities', 'school', 'students', 'extracurricular', 'sports'],
#  ['phones', 'cell', 'phone', 'policy', 'school'],
#  ['advice', 'people', 'ask', 'multiple', 'opinions'],
#  ['cars', 'driverless', 'car', 'driver', 'would'],
#  ['electoral', 'vote', 'college', 'president', 'electors'],
#  ['activities', 'school', 'students', 'extracurricular', 'sports'],
#  ['activities', 'school', 'students', 'extracurricular', 'sports'],
#  ['emotions', 'technology', 'facial', 'computer', 'could'],
#  ['venus', 'planet', 'earth', 'author', 'surface'],
#  ['advice', 'people', 'ask', 'multiple', 'opinions'],
#  ['phones', 'cell', 'phone', 'policy', 'school'],
#  ['activities', 'school', 'students', 'extracurricular', 'sports'],
#  ['advice', 'people', 'ask', 'multiple', 'opinions'],
#  ['cars', 'driverless', 'car', 'driver', 'would'],
#  ['summer', 'project', 'projects', 'students', 'designed'],
#  ['activities', 'school', 'students', 'extracurricular', 'sports'],
#  ['summer', 'project', 'projects', 'students', 'designed'],
#  ['generic_name', 'team', 'participate', 'activities', 'school'],
#  ['emotions', 'technology', 'facial', 'computer', 'could'],
#  ['car', 'cars', 'usage', 'pollution', 'air'],
#  ['advice', 'people', 'ask', 'multiple', 'opinions'],
#  ['car', 'cars', 'usage', 'pollution', 'air'],
#  ['summer', 'project', 'projects', 'students', 'designed'],
#  ['students', 'online', 'school', 'classes', 'home'],
#  ['students', 'online', 'school', 'classes', 'home'],
#  ['students', 'online', 'school', 'classes', 'home'],
#  ['phones', 'cell', 'phone', 'policy', 'school'],
#  ['phones', 'cell', 'phone', 'policy', 'school'],
#  ['generic_name', 'team', 'participate', 'activities', 'school'],
#  ['cars', 'driverless', 'car', 'driver', 'would'],
#  ['generic_name', 'team', 'participate', 'activities', 'school'],
#  ['summer', 'project', 'projects', 'students', 'designed'],
#  ['emotions', 'technology', 'facial', 'computer', 'could'],
#  ['venus', 'planet', 'earth', 'author', 'surface'],
#  ['electoral', 'vote', 'college', 'president', 'electors'],
#  ['car', 'cars', 'usage', 'pollution', 'air'],
#  ['cars', 'driverless', 'car', 'driver', 'would'],
#  ['summer', 'project', 'projects', 'students', 'designed'],
#  ['generic_name', 'team', 'participate', 'activities', 'school'],
#  ['summer', 'project', 'projects', 'students', 'designed'],
#  ['electoral', 'vote', 'college', 'president', 'electors'],
#  ['advice', 'people', 'ask', 'multiple', 'opinions'],
#  ['community', 'service', 'help', 'think', 'students'],
#  ['students', 'online', 'school', 'classes', 'home'],
#  ['electoral', 'vote', 'college', 'president', 'electors'],
#  ['car', 'cars', 'usage', 'pollution', 'air'],
#  ['face', 'mars', 'landform', 'aliens', 'natural'],
#  ['advice', 'people', 'ask', 'multiple', 'opinions'],
#  ['driving', 'phone', 'phones', 'cell', 'texting'],
#  ['emotions', 'technology', 'facial', 'computer', 'could'],
#  ['generic_name', 'team', 'participate', 'activities', 'school'],
#  ['cars', 'driverless', 'car', 'driver', 'would'],
#  ['activities', 'school', 'students', 'extracurricular', 'sports'],
#  ['generic_name', 'team', 'participate', 'activities', 'school'],
#  ['electoral', 'vote', 'college', 'president', 'electors'],
#  ['students', 'online', 'school', 'classes', 'home'],
#  ['car', 'cars', 'usage', 'pollution', 'air'],
#  ['electoral', 'vote', 'college', 'president', 'electors'],
#  ['advice', 'people', 'ask', 'multiple', 'opinions'],
#  ['advice', 'people', 'ask', 'multiple', 'opinions'],
#  ['phones', 'cell', 'phone', 'policy', 'school'],
#  ['activities', 'school', 'students', 'extracurricular', 'sports'],
#  ['summer', 'project', 'projects', 'students', 'designed'],
#  ['electoral', 'vote', 'college', 'president', 'electors'],
#  ['students', 'online', 'school', 'classes', 'home'],
#  ['generic_name', 'team', 'participate', 'activities', 'school'],
#  ['driving', 'phone', 'phones', 'cell', 'texting'],
#  ['face', 'mars', 'landform', 'aliens', 'natural'],
#  ['activities', 'school', 'students', 'extracurricular', 'sports'],
#  ['generic_name', 'team', 'participate', 'activities', 'school'],
#  ['electoral', 'vote', 'college', 'president', 'electors'],
#  ['phones', 'cell', 'phone', 'policy', 'school'],
#  ['generic_name', 'team', 'participate', 'activities', 'school'],
#  ['electoral', 'vote', 'college', 'president', 'electors'],
#  ['advice', 'people', 'ask', 'multiple', 'opinions'],
#  ['emotions', 'technology', 'facial', 'computer', 'could'],
#  ['face', 'mars', 'landform', 'aliens', 'natural'],
#  ['electoral', 'vote', 'college', 'president', 'electors'],
#  ['activities', 'school', 'students', 'extracurricular', 'sports'],
#  ['generic_name', 'team', 'participate', 'activities', 'school'],
#  ['driving', 'phone', 'phones', 'cell', 'texting'],
#  ['students', 'online', 'school', 'classes', 'home'],
#  ['activities', 'school', 'students', 'extracurricular', 'sports'],
#  ['activities', 'school', 'students', 'extracurricular', 'sports'],
#  ['advice', 'people', 'ask', 'multiple', 'opinions'],
#  ['venus', 'planet', 'earth', 'author', 'surface'],
#  ['electoral', 'vote', 'college', 'president', 'electors'],
#  ['car', 'cars', 'usage', 'pollution', 'air'],
#  ['summer', 'project', 'projects', 'students', 'designed'],
#  ['generic_name', 'team', 'participate', 'activities', 'school'],
#  ['electoral', 'vote', 'college', 'president', 'electors'],
#  ['phones', 'cell', 'phone', 'policy', 'school'],
#  ['electoral', 'vote', 'college', 'president', 'electors'],
#  ['community', 'service', 'help', 'think', 'students'],
#  ['advice', 'people', 'ask', 'multiple', 'opinions'],
#  ['activities', 'school', 'students', 'extracurricular', 'sports'],
#  ['emotions', 'technology', 'facial', 'computer', 'could'],
#  ['cars', 'driverless', 'car', 'driver', 'would'],
#  ['summer', 'project', 'projects', 'students', 'designed'],
#  ['electoral', 'vote', 'college', 'president', 'electors'],
#  ['generic_name', 'team', 'participate', 'activities', 'school'],
#  ['phones', 'cell', 'phone', 'policy', 'school'],
#  ['activities', 'school', 'students', 'extracurricular', 'sports'],
#  ['advice', 'people', 'ask', 'multiple', 'opinions'],
#  ['activities', 'school', 'students', 'extracurricular', 'sports'],
#  ['generic_name', 'team', 'participate', 'activities', 'school'],
#  ['phones', 'cell', 'phone', 'policy', 'school'],
#  ['venus', 'planet', 'earth', 'author', 'surface'],
#  ['emotions', 'technology', 'facial', 'computer', 'could'],
#  ['activities', 'school', 'students', 'extracurricular', 'sports'],
#  ['driving', 'phone', 'phones', 'cell', 'texting'],
#  ['students', 'online', 'school', 'classes', 'home'],
#  ['driving', 'phone', 'phones', 'cell', 'texting'],
#  ['electoral', 'vote', 'college', 'president', 'electors'],
#  ['face', 'mars', 'landform', 'aliens', 'natural'],
#  ['electoral', 'vote', 'college', 'president', 'electors'],
#  ['emotions', 'technology', 'facial', 'computer', 'could'],
#  ['phones', 'cell', 'phone', 'policy', 'school'],
#  ['electoral', 'vote', 'college', 'president', 'electors'],
#  ['students', 'online', 'school', 'classes', 'home'],
#  ['activities', 'school', 'students', 'extracurricular', 'sports'],
#  ['car', 'cars', 'usage', 'pollution', 'air'],
#  ['phones', 'cell', 'phone', 'policy', 'school'],
#  ['generic_name', 'team', 'participate', 'activities', 'school'],
#  ['cars', 'driverless', 'car', 'driver', 'would'],
#  ['activities', 'school', 'students', 'extracurricular', 'sports'],
#  ['cars', 'driverless', 'car', 'driver', 'would'],
#  ['emotions', 'technology', 'facial', 'computer', 'could'],
#  ['electoral', 'vote', 'college', 'president', 'electors'],
#  ['summer', 'project', 'projects', 'students', 'designed'],
#  ['students', 'online', 'school', 'classes', 'home'],
#  ['electoral', 'vote', 'college', 'president', 'electors'],
#  ['cars', 'driverless', 'car', 'driver', 'would'],
#  ['car', 'cars', 'usage', 'pollution', 'air'],
#  ['activities', 'school', 'students', 'extracurricular', 'sports'],
#  ['activities', 'school', 'students', 'extracurricular', 'sports'],
#  ['advice', 'people', 'ask', 'multiple', 'opinions'],
#  ['community', 'service', 'help', 'think', 'students'],
#  ['advice', 'people', 'ask', 'multiple', 'opinions'],
#  ['advice', 'people', 'ask', 'multiple', 'opinions'],
#  ['car', 'cars', 'usage', 'pollution', 'air'],
#  ['phones', 'cell', 'phone', 'policy', 'school'],
#  ['advice', 'people', 'ask', 'multiple', 'opinions'],
#  ['activities', 'school', 'students', 'extracurricular', 'sports'],
#  ['emotions', 'technology', 'facial', 'computer', 'could'],
#  ['summer', 'project', 'projects', 'students', 'designed'],
#  ['electoral', 'vote', 'college', 'president', 'electors'],
#  ['electoral', 'vote', 'college', 'president', 'electors'],
#  ['summer', 'project', 'projects', 'students', 'designed'],
#  ['generic_name', 'team', 'participate', 'activities', 'school'],
#  ['venus', 'planet', 'earth', 'author', 'surface'],
#  ['activities', 'school', 'students', 'extracurricular', 'sports'],
#  ['community', 'service', 'help', 'think', 'students'],
#  ['students', 'online', 'school', 'classes', 'home'],
#  ['students', 'online', 'school', 'classes', 'home'],
#  ['advice', 'people', 'ask', 'multiple', 'opinions'],
#  ['emotions', 'technology', 'facial', 'computer', 'could'],
#  ['generic_name', 'team', 'participate', 'activities', 'school'],
#  ['emotions', 'technology', 'facial', 'computer', 'could'],
#  ['activities', 'school', 'students', 'extracurricular', 'sports'],
#  ['emotions', 'technology', 'facial', 'computer', 'could'],
#  ['advice', 'people', 'ask', 'multiple', 'opinions'],
#  ['advice', 'people', 'ask', 'multiple', 'opinions'],
#  ['electoral', 'vote', 'college', 'president', 'electors'],
#  ['car', 'cars', 'usage', 'pollution', 'air'],
#  ['venus', 'planet', 'earth', 'author', 'surface'],
#  ['generic_name', 'team', 'participate', 'activities', 'school'],
#  ['activities', 'school', 'students', 'extracurricular', 'sports'],
#  ['advice', 'people', 'ask', 'multiple', 'opinions'],
#  ['electoral', 'vote', 'college', 'president', 'electors'],
#  ['advice', 'people', 'ask', 'multiple', 'opinions'],
#  ['activities', 'school', 'students', 'extracurricular', 'sports'],
#  ['summer', 'project', 'projects', 'students', 'designed'],
#  ['face', 'mars', 'landform', 'aliens', 'natural'],
#  ['advice', 'people', 'ask', 'multiple', 'opinions'],
#  ['generic_name', 'team', 'participate', 'activities', 'school'],
#  ['phones', 'cell', 'phone', 'policy', 'school'],
#  ['generic_name', 'team', 'participate', 'activities', 'school'],
#  ['cars', 'driverless', 'car', 'driver', 'would'],
#  ['activities', 'school', 'students', 'extracurricular', 'sports'],
#  ['electoral', 'vote', 'college', 'president', 'electors'],
#  ['community', 'service', 'help', 'think', 'students'],
#  ['face', 'mars', 'landform', 'aliens', 'natural'],
#  ['face', 'mars', 'landform', 'aliens', 'natural'],
#  ['car', 'cars', 'usage', 'pollution', 'air'],
#  ['cars', 'driverless', 'car', 'driver', 'would'],
#  ['electoral', 'vote', 'college', 'president', 'electors'],
#  ['generic_name', 'team', 'participate', 'activities', 'school'],
#  ['generic_name', 'team', 'participate', 'activities', 'school'],
#  ['summer', 'project', 'projects', 'students', 'designed'],
#  ['phones', 'cell', 'phone', 'policy', 'school'],
#  ['emotions', 'technology', 'facial', 'computer', 'could'],
#  ['activities', 'school', 'students', 'extracurricular', 'sports'],
#  ['cars', 'driverless', 'car', 'driver', 'would'],
#  ['venus', 'planet', 'earth', 'author', 'surface'],
#  ['emotions', 'technology', 'facial', 'computer', 'could'],
#  ['venus', 'planet', 'earth', 'author', 'surface'],
#  ['venus', 'planet', 'earth', 'author', 'surface'],
#  ['advice', 'people', 'ask', 'multiple', 'opinions'],
#  ['summer', 'project', 'projects', 'students', 'designed'],
#  ['venus', 'planet', 'earth', 'author', 'surface'],
#  ['electoral', 'vote', 'college', 'president', 'electors'],
#  ['community', 'service', 'help', 'think', 'students'],
#  ['venus', 'planet', 'earth', 'author', 'surface'],
#  ['emotions', 'technology', 'facial', 'computer', 'could'],
#  ['emotions', 'technology', 'facial', 'computer', 'could'],
#  ['generic_name', 'team', 'participate', 'activities', 'school'],
#  ['driving', 'phone', 'phones', 'cell', 'texting'],
#  ['face', 'mars', 'landform', 'aliens', 'natural'],
#  ['activities', 'school', 'students', 'extracurricular', 'sports'],
#  ['summer', 'project', 'projects', 'students', 'designed'],
#  ['venus', 'planet', 'earth', 'author', 'surface'],
#  ['face', 'mars', 'landform', 'aliens', 'natural'],
#  ['generic_name', 'team', 'participate', 'activities', 'school'],
#  ['cars', 'driverless', 'car', 'driver', 'would'],
#  ['students', 'online', 'school', 'classes', 'home'],
#  ['students', 'online', 'school', 'classes', 'home'],
#  ['electoral', 'vote', 'college', 'president', 'electors'],
#  ['students', 'online', 'school', 'classes', 'home'],
#  ['electoral', 'vote', 'college', 'president', 'electors'],
#  ['cars', 'driverless', 'car', 'driver', 'would'],
#  ['generic_name', 'team', 'participate', 'activities', 'school'],
#  ['generic_name', 'team', 'participate', 'activities', 'school'],
#  ['car', 'cars', 'usage', 'pollution', 'air'],
#  ['students', 'online', 'school', 'classes', 'home'],
#  ['generic_name', 'team', 'participate', 'activities', 'school'],
#  ['activities', 'school', 'students', 'extracurricular', 'sports'],
#  ['electoral', 'vote', 'college', 'president', 'electors'],
#  ['summer', 'project', 'projects', 'students', 'designed'],
#  ['activities', 'school', 'students', 'extracurricular', 'sports'],
#  ['phones', 'cell', 'phone', 'policy', 'school'],
#  ['cars', 'driverless', 'car', 'driver', 'would'],
#  ['phones', 'cell', 'phone', 'policy', 'school'],
#  ['advice', 'people', 'ask', 'multiple', 'opinions'],
#  ['generic_name', 'team', 'participate', 'activities', 'school'],
#  ['generic_name', 'team', 'participate', 'activities', 'school'],
#  ['summer', 'project', 'projects', 'students', 'designed'],
#  ['activities', 'school', 'students', 'extracurricular', 'sports'],
#  ['cars', 'driverless', 'car', 'driver', 'would'],
#  ['activities', 'school', 'students', 'extracurricular', 'sports'],
#  ['generic_name', 'team', 'participate', 'activities', 'school'],
#  ['electoral', 'vote', 'college', 'president', 'electors'],
#  ['summer', 'project', 'projects', 'students', 'designed'],
#  ['face', 'mars', 'landform', 'aliens', 'natural'],
#  ['generic_name', 'team', 'participate', 'activities', 'school'],
#  ['car', 'cars', 'usage', 'pollution', 'air'],
#  ['community', 'service', 'help', 'think', 'students'],
#  ['generic_name', 'team', 'participate', 'activities', 'school'],
#  ['electoral', 'vote', 'college', 'president', 'electors'],
#  ['phones', 'cell', 'phone', 'policy', 'school'],
#  ['venus', 'planet', 'earth', 'author', 'surface'],
#  ['advice', 'people', 'ask', 'multiple', 'opinions'],
#  ['electoral', 'vote', 'college', 'president', 'electors'],
#  ['students', 'online', 'school', 'classes', 'home'],
#  ['community', 'service', 'help', 'think', 'students'],
#  ['face', 'mars', 'landform', 'aliens', 'natural'],
#  ['generic_name', 'team', 'participate', 'activities', 'school'],
#  ['driving', 'phone', 'phones', 'cell', 'texting'],
#  ['generic_name', 'team', 'participate', 'activities', 'school'],
#  ['emotions', 'technology', 'facial', 'computer', 'could'],
#  ['electoral', 'vote', 'college', 'president', 'electors'],
#  ['cars', 'driverless', 'car', 'driver', 'would'],
#  ['generic_name', 'team', 'participate', 'activities', 'school'],
#  ['electoral', 'vote', 'college', 'president', 'electors'],
#  ['cars', 'driverless', 'car', 'driver', 'would'],
#  ['advice', 'people', 'ask', 'multiple', 'opinions'],
#  ['activities', 'school', 'students', 'extracurricular', 'sports'],
#  ['community', 'service', 'help', 'think', 'students'],
#  ['generic_name', 'team', 'participate', 'activities', 'school'],
#  ['electoral', 'vote', 'college', 'president', 'electors'],
#  ['activities', 'school', 'students', 'extracurricular', 'sports'],
#  ['activities', 'school', 'students', 'extracurricular', 'sports'],
#  ['generic_name', 'team', 'participate', 'activities', 'school'],
#  ['summer', 'project', 'projects', 'students', 'designed'],
#  ['emotions', 'technology', 'facial', 'computer', 'could'],
#  ['cars', 'driverless', 'car', 'driver', 'would'],
#  ['car', 'cars', 'usage', 'pollution', 'air'],
#  ['generic_name', 'team', 'participate', 'activities', 'school'],
#  ['electoral', 'vote', 'college', 'president', 'electors'],
#  ['activities', 'school', 'students', 'extracurricular', 'sports'],
#  ['students', 'online', 'school', 'classes', 'home'],
#  ['electoral', 'vote', 'college', 'president', 'electors'],
#  ['advice', 'people', 'ask', 'multiple', 'opinions'],
#  ['electoral', 'vote', 'college', 'president', 'electors'],
#  ['advice', 'people', 'ask', 'multiple', 'opinions'],
#  ['summer', 'project', 'projects', 'students', 'designed'],
#  ['emotions', 'technology', 'facial', 'computer', 'could'],
#  ['advice', 'people', 'ask', 'multiple', 'opinions'],
#  ['electoral', 'vote', 'college', 'president', 'electors'],
#  ['activities', 'school', 'students', 'extracurricular', 'sports'],
#  ['car', 'cars', 'usage', 'pollution', 'air'],
#  ['students', 'online', 'school', 'classes', 'home'],
#  ['activities', 'school', 'students', 'extracurricular', 'sports'],
#  ['advice', 'people', 'ask', 'multiple', 'opinions'],
#  ['activities', 'school', 'students', 'extracurricular', 'sports'],
#  ['electoral', 'vote', 'college', 'president', 'electors'],
#  ['face', 'mars', 'landform', 'aliens', 'natural'],
#  ['generic_name', 'team', 'participate', 'activities', 'school'],
#  ['cars', 'driverless', 'car', 'driver', 'would'],
#  ['cars', 'driverless', 'car', 'driver', 'would'],
#  ['cars', 'driverless', 'car', 'driver', 'would'],
#  ['emotions', 'technology', 'facial', 'computer', 'could'],
#  ['students', 'online', 'school', 'classes', 'home'],
#  ['venus', 'planet', 'earth', 'author', 'surface'],
#  ['car', 'cars', 'usage', 'pollution', 'air'],
#  ['face', 'mars', 'landform', 'aliens', 'natural'],
#  ['advice', 'people', 'ask', 'multiple', 'opinions'],
#  ['students', 'online', 'school', 'classes', 'home'],
#  ['students', 'online', 'school', 'classes', 'home'],
#  ['students', 'online', 'school', 'classes', 'home'],
#  ['generic_name', 'team', 'participate', 'activities', 'school'],
#  ['students', 'online', 'school', 'classes', 'home'],
#  ['advice', 'people', 'ask', 'multiple', 'opinions'],
#  ['generic_name', 'team', 'participate', 'activities', 'school'],
#  ['emotions', 'technology', 'facial', 'computer', 'could'],
#  ['cars', 'driverless', 'car', 'driver', 'would'],
#  ['face', 'mars', 'landform', 'aliens', 'natural'],
#  ['activities', 'school', 'students', 'extracurricular', 'sports'],
#  ['emotions', 'technology', 'facial', 'computer', 'could'],
#  ['advice', 'people', 'ask', 'multiple', 'opinions'],
#  ['electoral', 'vote', 'college', 'president', 'electors'],
#  ['generic_name', 'team', 'participate', 'activities', 'school'],
#  ['venus', 'planet', 'earth', 'author', 'surface'],
#  ['emotions', 'technology', 'facial', 'computer', 'could'],
#  ['face', 'mars', 'landform', 'aliens', 'natural'],
#  ['advice', 'people', 'ask', 'multiple', 'opinions'],
#  ['emotions', 'technology', 'facial', 'computer', 'could'],
#  ['face', 'mars', 'landform', 'aliens', 'natural'],
#  ['electoral', 'vote', 'college', 'president', 'electors'],
#  ['summer', 'project', 'projects', 'students', 'designed'],
#  ['students', 'online', 'school', 'classes', 'home'],
#  ['venus', 'planet', 'earth', 'author', 'surface'],
#  ['driving', 'phone', 'phones', 'cell', 'texting'],
#  ['activities', 'school', 'students', 'extracurricular', 'sports'],
#  ['venus', 'planet', 'earth', 'author', 'surface'],
#  ['summer', 'project', 'projects', 'students', 'designed'],
#  ['car', 'cars', 'usage', 'pollution', 'air'],
#  ['generic_name', 'team', 'participate', 'activities', 'school'],
#  ['community', 'service', 'help', 'think', 'students'],
#  ['students', 'online', 'school', 'classes', 'home'],
#  ['students', 'online', 'school', 'classes', 'home'],
#  ['community', 'service', 'help', 'think', 'students'],
#  ['cars', 'driverless', 'car', 'driver', 'would'],
#  ['driving', 'phone', 'phones', 'cell', 'texting'],
#  ['generic_name', 'team', 'participate', 'activities', 'school'],
#  ['students', 'online', 'school', 'classes', 'home'],
#  ['face', 'mars', 'landform', 'aliens', 'natural'],
#  ['activities', 'school', 'students', 'extracurricular', 'sports'],
#  ['cars', 'driverless', 'car', 'driver', 'would'],
#  ['emotions', 'technology', 'facial', 'computer', 'could'],
#  ['summer', 'project', 'projects', 'students', 'designed'],
#  ['cars', 'driverless', 'car', 'driver', 'would'],
#  ['students', 'online', 'school', 'classes', 'home'],
#  ['generic_name', 'team', 'participate', 'activities', 'school'],
#  ['advice', 'people', 'ask', 'multiple', 'opinions'],
#  ['activities', 'school', 'students', 'extracurricular', 'sports'],
#  ['cars', 'driverless', 'car', 'driver', 'would'],
#  ['students', 'online', 'school', 'classes', 'home'],
#  ['venus', 'planet', 'earth', 'author', 'surface'],
#  ['advice', 'people', 'ask', 'multiple', 'opinions'],
#  ['community', 'service', 'help', 'think', 'students'],
#  ['emotions', 'technology', 'facial', 'computer', 'could'],
#  ['venus', 'planet', 'earth', 'author', 'surface'],
#  ['cars', 'driverless', 'car', 'driver', 'would'],
#  ['driving', 'phone', 'phones', 'cell', 'texting'],
#  ['advice', 'people', 'ask', 'multiple', 'opinions'],
#  ['activities', 'school', 'students', 'extracurricular', 'sports'],
#  ['car', 'cars', 'usage', 'pollution', 'air'],
#  ['electoral', 'vote', 'college', 'president', 'electors'],
#  ['students', 'online', 'school', 'classes', 'home'],
#  ['car', 'cars', 'usage', 'pollution', 'air'],
#  ['electoral', 'vote', 'college', 'president', 'electors'],
#  ['advice', 'people', 'ask', 'multiple', 'opinions'],
#  ['emotions', 'technology', 'facial', 'computer', 'could'],
#  ['face', 'mars', 'landform', 'aliens', 'natural'],
#  ['generic_name', 'team', 'participate', 'activities', 'school'],
#  ['activities', 'school', 'students', 'extracurricular', 'sports'],
#  ['electoral', 'vote', 'college', 'president', 'electors'],
#  ['car', 'cars', 'usage', 'pollution', 'air'],
#  ['cars', 'driverless', 'car', 'driver', 'would'],
#  ['students', 'online', 'school', 'classes', 'home'],
#  ['students', 'online', 'school', 'classes', 'home'],
#  ['emotions', 'technology', 'facial', 'computer', 'could'],
#  ['generic_name', 'team', 'participate', 'activities', 'school'],
#  ['activities', 'school', 'students', 'extracurricular', 'sports'],
#  ['electoral', 'vote', 'college', 'president', 'electors'],
#  ['face', 'mars', 'landform', 'aliens', 'natural'],
#  ['community', 'service', 'help', 'think', 'students'],
#  ['emotions', 'technology', 'facial', 'computer', 'could'],
#  ['face', 'mars', 'landform', 'aliens', 'natural'],
#  ['advice', 'people', 'ask', 'multiple', 'opinions'],
#  ['electoral', 'vote', 'college', 'president', 'electors'],
#  ['generic_name', 'team', 'participate', 'activities', 'school'],
#  ['generic_name', 'team', 'participate', 'activities', 'school'],
#  ['phones', 'cell', 'phone', 'policy', 'school'],
#  ['car', 'cars', 'usage', 'pollution', 'air'],
#  ['generic_name', 'team', 'participate', 'activities', 'school'],
#  ['car', 'cars', 'usage', 'pollution', 'air'],
#  ['car', 'cars', 'usage', 'pollution', 'air'],
#  ['car', 'cars', 'usage', 'pollution', 'air'],
#  ['emotions', 'technology', 'facial', 'computer', 'could'],
#  ['advice', 'people', 'ask', 'multiple', 'opinions'],
#  ['activities', 'school', 'students', 'extracurricular', 'sports'],
#  ['activities', 'school', 'students', 'extracurricular', 'sports'],
#  ['activities', 'school', 'students', 'extracurricular', 'sports'],
#  ['electoral', 'vote', 'college', 'president', 'electors'],
#  ['activities', 'school', 'students', 'extracurricular', 'sports'],
#  ['summer', 'project', 'projects', 'students', 'designed'],
#  ['generic_name', 'team', 'participate', 'activities', 'school'],
#  ['venus', 'planet', 'earth', 'author', 'surface'],
#  ['advice', 'people', 'ask', 'multiple', 'opinions'],
#  ['electoral', 'vote', 'college', 'president', 'electors'],
#  ['face', 'mars', 'landform', 'aliens', 'natural'],
#  ['advice', 'people', 'ask', 'multiple', 'opinions'],
#  ['venus', 'planet', 'earth', 'author', 'surface'],
#  ['advice', 'people', 'ask', 'multiple', 'opinions'],
#  ['cars', 'driverless', 'car', 'driver', 'would'],
#  ['activities', 'school', 'students', 'extracurricular', 'sports'],
#  ['venus', 'planet', 'earth', 'author', 'surface'],
#  ['students', 'online', 'school', 'classes', 'home'],
#  ['electoral', 'vote', 'college', 'president', 'electors'],
#  ['community', 'service', 'help', 'think', 'students'],
#  ['students', 'online', 'school', 'classes', 'home'],
#  ['face', 'mars', 'landform', 'aliens', 'natural'],
#  ['summer', 'project', 'projects', 'students', 'designed'],
#  ['emotions', 'technology', 'facial', 'computer', 'could'],
#  ['face', 'mars', 'landform', 'aliens', 'natural'],
#  ['venus', 'planet', 'earth', 'author', 'surface'],
#  ['activities', 'school', 'students', 'extracurricular', 'sports'],
#  ['driving', 'phone', 'phones', 'cell', 'texting'],
#  ['advice', 'people', 'ask', 'multiple', 'opinions'],
#  ['advice', 'people', 'ask', 'multiple', 'opinions'],
#  ['students', 'online', 'school', 'classes', 'home'],
#  ['phones', 'cell', 'phone', 'policy', 'school'],
#  ['generic_name', 'team', 'participate', 'activities', 'school'],
#  ['electoral', 'vote', 'college', 'president', 'electors'],
#  ['generic_name', 'team', 'participate', 'activities', 'school'],
#  ['cars', 'driverless', 'car', 'driver', 'would'],
#  ['generic_name', 'team', 'participate', 'activities', 'school'],
#  ['generic_name', 'team', 'participate', 'activities', 'school'],
#  ['phones', 'cell', 'phone', 'policy', 'school'],
#  ['cars', 'driverless', 'car', 'driver', 'would'],
#  ['electoral', 'vote', 'college', 'president', 'electors'],
#  ['activities', 'school', 'students', 'extracurricular', 'sports'],
#  ['summer', 'project', 'projects', 'students', 'designed'],
#  ['car', 'cars', 'usage', 'pollution', 'air'],
#  ['generic_name', 'team', 'participate', 'activities', 'school'],
#  ['venus', 'planet', 'earth', 'author', 'surface'],
#  ['advice', 'people', 'ask', 'multiple', 'opinions'],
#  ['advice', 'people', 'ask', 'multiple', 'opinions'],
#  ['cars', 'driverless', 'car', 'driver', 'would'],
#  ['car', 'cars', 'usage', 'pollution', 'air'],
#  ['cars', 'driverless', 'car', 'driver', 'would'],
#  ['electoral', 'vote', 'college', 'president', 'electors'],
#  ['phones', 'cell', 'phone', 'policy', 'school'],
#  ['summer', 'project', 'projects', 'students', 'designed'],
#  ['activities', 'school', 'students', 'extracurricular', 'sports'],
#  ['advice', 'people', 'ask', 'multiple', 'opinions'],
#  ['electoral', 'vote', 'college', 'president', 'electors'],
#  ['car', 'cars', 'usage', 'pollution', 'air'],
#  ['driving', 'phone', 'phones', 'cell', 'texting'],
#  ['cars', 'driverless', 'car', 'driver', 'would'],
#  ['phones', 'cell', 'phone', 'policy', 'school'],
#  ['emotions', 'technology', 'facial', 'computer', 'could'],
#  ['generic_name', 'team', 'participate', 'activities', 'school'],
#  ['advice', 'people', 'ask', 'multiple', 'opinions'],
#  ['venus', 'planet', 'earth', 'author', 'surface'],
#  ['emotions', 'technology', 'facial', 'computer', 'could'],
#  ['generic_name', 'team', 'participate', 'activities', 'school'],
#  ['electoral', 'vote', 'college', 'president', 'electors'],
#  ['generic_name', 'team', 'participate', 'activities', 'school'],
#  ['face', 'mars', 'landform', 'aliens', 'natural'],
#  ['activities', 'school', 'students', 'extracurricular', 'sports'],
#  ['venus', 'planet', 'earth', 'author', 'surface'],
#  ['advice', 'people', 'ask', 'multiple', 'opinions'],
#  ['car', 'cars', 'usage', 'pollution', 'air'],
#  ['emotions', 'technology', 'facial', 'computer', 'could'],
#  ['cars', 'driverless', 'car', 'driver', 'would'],
#  ['students', 'online', 'school', 'classes', 'home'],
#  ['car', 'cars', 'usage', 'pollution', 'air'],
#  ['generic_name', 'team', 'participate', 'activities', 'school'],
#  ['face', 'mars', 'landform', 'aliens', 'natural'],
#  ['advice', 'people', 'ask', 'multiple', 'opinions'],
#  ['electoral', 'vote', 'college', 'president', 'electors'],
#  ['face', 'mars', 'landform', 'aliens', 'natural'],
#  ['face', 'mars', 'landform', 'aliens', 'natural'],
#  ['emotions', 'technology', 'facial', 'computer', 'could'],
#  ['community', 'service', 'help', 'think', 'students'],
#  ['activities', 'school', 'students', 'extracurricular', 'sports'],
#  ['advice', 'people', 'ask', 'multiple', 'opinions'],
#  ['cars', 'driverless', 'car', 'driver', 'would'],
#  ['summer', 'project', 'projects', 'students', 'designed'],
#  ['phones', 'cell', 'phone', 'policy', 'school'],
#  ['advice', 'people', 'ask', 'multiple', 'opinions'],
#  ['generic_name', 'team', 'participate', 'activities', 'school'],
#  ['activities', 'school', 'students', 'extracurricular', 'sports'],
#  ['face', 'mars', 'landform', 'aliens', 'natural'],
#  ['students', 'online', 'school', 'classes', 'home'],
#  ['cars', 'driverless', 'car', 'driver', 'would'],
#  ['activities', 'school', 'students', 'extracurricular', 'sports'],
#  ['activities', 'school', 'students', 'extracurricular', 'sports'],
#  ['activities', 'school', 'students', 'extracurricular', 'sports'],
#  ['car', 'cars', 'usage', 'pollution', 'air'],
#  ['car', 'cars', 'usage', 'pollution', 'air'],
#  ['activities', 'school', 'students', 'extracurricular', 'sports'],
#  ['emotions', 'technology', 'facial', 'computer', 'could'],
#  ['cars', 'driverless', 'car', 'driver', 'would'],
#  ['phones', 'cell', 'phone', 'policy', 'school'],
#  ['electoral', 'vote', 'college', 'president', 'electors'],
#  ['generic_name', 'team', 'participate', 'activities', 'school'],
#  ['generic_name', 'team', 'participate', 'activities', 'school'],
#  ['students', 'online', 'school', 'classes', 'home'],
#  ['activities', 'school', 'students', 'extracurricular', 'sports'],
#  ['activities', 'school', 'students', 'extracurricular', 'sports'],
#  ['activities', 'school', 'students', 'extracurricular', 'sports'],
#  ['cars', 'driverless', 'car', 'driver', 'would'],
#  ['cars', 'driverless', 'car', 'driver', 'would'],
#  ['cars', 'driverless', 'car', 'driver', 'would'],
#  ['generic_name', 'team', 'participate', 'activities', 'school'],
#  ['cars', 'driverless', 'car', 'driver', 'would'],
#  ['driving', 'phone', 'phones', 'cell', 'texting'],
#  ['venus', 'planet', 'earth', 'author', 'surface'],
#  ['electoral', 'vote', 'college', 'president', 'electors'],
#  ['venus', 'planet', 'earth', 'author', 'surface'],
#  ['emotions', 'technology', 'facial', 'computer', 'could'],
#  ['activities', 'school', 'students', 'extracurricular', 'sports'],
#  ['electoral', 'vote', 'college', 'president', 'electors'],
#  ['advice', 'people', 'ask', 'multiple', 'opinions'],
#  ['cars', 'driverless', 'car', 'driver', 'would'],
#  ['community', 'service', 'help', 'think', 'students'],
#  ['venus', 'planet', 'earth', 'author', 'surface'],
#  ['generic_name', 'team', 'participate', 'activities', 'school'],
#  ['cars', 'driverless', 'car', 'driver', 'would'],
#  ['electoral', 'vote', 'college', 'president', 'electors'],
#  ['car', 'cars', 'usage', 'pollution', 'air'],
#  ['summer', 'project', 'projects', 'students', 'designed'],
#  ['generic_name', 'team', 'participate', 'activities', 'school'],
#  ['advice', 'people', 'ask', 'multiple', 'opinions'],
#  ['community', 'service', 'help', 'think', 'students'],
#  ['phones', 'cell', 'phone', 'policy', 'school'],
#  ['students', 'online', 'school', 'classes', 'home'],
#  ['electoral', 'vote', 'college', 'president', 'electors'],
#  ['face', 'mars', 'landform', 'aliens', 'natural'],
#  ['electoral', 'vote', 'college', 'president', 'electors'],
#  ['venus', 'planet', 'earth', 'author', 'surface'],
#  ['activities', 'school', 'students', 'extracurricular', 'sports'],
#  ['cars', 'driverless', 'car', 'driver', 'would'],
#  ['summer', 'project', 'projects', 'students', 'designed'],
#  ['advice', 'people', 'ask', 'multiple', 'opinions'],
#  ['car', 'cars', 'usage', 'pollution', 'air'],
#  ['electoral', 'vote', 'college', 'president', 'electors'],
#  ['phones', 'cell', 'phone', 'policy', 'school'],
#  ['driving', 'phone', 'phones', 'cell', 'texting'],
#  ['phones', 'cell', 'phone', 'policy', 'school'],
#  ['generic_name', 'team', 'participate', 'activities', 'school'],
#  ['advice', 'people', 'ask', 'multiple', 'opinions'],
#  ['students', 'online', 'school', 'classes', 'home'],
#  ['cars', 'driverless', 'car', 'driver', 'would'],
#  ['generic_name', 'team', 'participate', 'activities', 'school'],
#  ['activities', 'school', 'students', 'extracurricular', 'sports'],
#  ['driving', 'phone', 'phones', 'cell', 'texting'],
#  ['driving', 'phone', 'phones', 'cell', 'texting'],
#  ['activities', 'school', 'students', 'extracurricular', 'sports'],
#  ['generic_name', 'team', 'participate', 'activities', 'school'],
#  ['generic_name', 'team', 'participate', 'activities', 'school'],
#  ['car', 'cars', 'usage', 'pollution', 'air'],
#  ['car', 'cars', 'usage', 'pollution', 'air'],
#  ['electoral', 'vote', 'college', 'president', 'electors'],
#  ['generic_name', 'team', 'participate', 'activities', 'school'],
#  ['venus', 'planet', 'earth', 'author', 'surface'],
#  ['activities', 'school', 'students', 'extracurricular', 'sports'],
#  ['community', 'service', 'help', 'think', 'students'],
#  ['emotions', 'technology', 'facial', 'computer', 'could'],
#  ['cars', 'driverless', 'car', 'driver', 'would'],
#  ['summer', 'project', 'projects', 'students', 'designed'],
#  ['electoral', 'vote', 'college', 'president', 'electors'],
#  ['phones', 'cell', 'phone', 'policy', 'school'],
#  ['car', 'cars', 'usage', 'pollution', 'air'],
#  ['driving', 'phone', 'phones', 'cell', 'texting'],
#  ['generic_name', 'team', 'participate', 'activities', 'school'],
#  ['activities', 'school', 'students', 'extracurricular', 'sports'],
#  ['activities', 'school', 'students', 'extracurricular', 'sports'],
#  ['electoral', 'vote', 'college', 'president', 'electors'],
#  ['cars', 'driverless', 'car', 'driver', 'would'],
#  ['emotions', 'technology', 'facial', 'computer', 'could'],
#  ['summer', 'project', 'projects', 'students', 'designed'],
#  ['activities', 'school', 'students', 'extracurricular', 'sports'],
#  ['phones', 'cell', 'phone', 'policy', 'school'],
#  ['activities', 'school', 'students', 'extracurricular', 'sports'],
#  ['electoral', 'vote', 'college', 'president', 'electors'],
#  ['students', 'online', 'school', 'classes', 'home'],
#  ['generic_name', 'team', 'participate', 'activities', 'school'],
#  ['car', 'cars', 'usage', 'pollution', 'air'],
#  ['activities', 'school', 'students', 'extracurricular', 'sports'],
#  ['car', 'cars', 'usage', 'pollution', 'air'],
#  ['emotions', 'technology', 'facial', 'computer', 'could'],
#  ['activities', 'school', 'students', 'extracurricular', 'sports'],
#  ['car', 'cars', 'usage', 'pollution', 'air'],
#  ['generic_name', 'team', 'participate', 'activities', 'school'],
#  ['students', 'online', 'school', 'classes', 'home'],
#  ['driving', 'phone', 'phones', 'cell', 'texting'],
#  ['driving', 'phone', 'phones', 'cell', 'texting'],
#  ['activities', 'school', 'students', 'extracurricular', 'sports'],
#  ['activities', 'school', 'students', 'extracurricular', 'sports'],
#  ['community', 'service', 'help', 'think', 'students'],
#  ['driving', 'phone', 'phones', 'cell', 'texting'],
#  ['students', 'online', 'school', 'classes', 'home'],
#  ['activities', 'school', 'students', 'extracurricular', 'sports'],
#  ['generic_name', 'team', 'participate', 'activities', 'school'],
#  ['electoral', 'vote', 'college', 'president', 'electors'],
#  ['driving', 'phone', 'phones', 'cell', 'texting'],
#  ['venus', 'planet', 'earth', 'author', 'surface'],
#  ['electoral', 'vote', 'college', 'president', 'electors'],
#  ['generic_name', 'team', 'participate', 'activities', 'school'],
#  ['activities', 'school', 'students', 'extracurricular', 'sports'],
#  ['phones', 'cell', 'phone', 'policy', 'school'],
#  ['advice', 'people', 'ask', 'multiple', 'opinions'],
#  ['generic_name', 'team', 'participate', 'activities', 'school'],
#  ['advice', 'people', 'ask', 'multiple', 'opinions'],
#  ['face', 'mars', 'landform', 'aliens', 'natural'],
#  ['community', 'service', 'help', 'think', 'students'],
#  ['venus', 'planet', 'earth', 'author', 'surface'],
#  ['generic_name', 'team', 'participate', 'activities', 'school'],
#  ['car', 'cars', 'usage', 'pollution', 'air'],
#  ['phones', 'cell', 'phone', 'policy', 'school'],
#  ['summer', 'project', 'projects', 'students', 'designed'],
#  ['electoral', 'vote', 'college', 'president', 'electors'],
#  ['summer', 'project', 'projects', 'students', 'designed'],
#  ['emotions', 'technology', 'facial', 'computer', 'could'],
#  ['students', 'online', 'school', 'classes', 'home'],
#  ['electoral', 'vote', 'college', 'president', 'electors'],
#  ['venus', 'planet', 'earth', 'author', 'surface'],
#  ['advice', 'people', 'ask', 'multiple', 'opinions'],
#  ['phones', 'cell', 'phone', 'policy', 'school'],
#  ['phones', 'cell', 'phone', 'policy', 'school'],
#  ['students', 'online', 'school', 'classes', 'home'],
#  ['community', 'service', 'help', 'think', 'students'],
#  ['students', 'online', 'school', 'classes', 'home'],
#  ['electoral', 'vote', 'college', 'president', 'electors'],
#  ['summer', 'project', 'projects', 'students', 'designed'],
#  ['students', 'online', 'school', 'classes', 'home'],
#  ['phones', 'cell', 'phone', 'policy', 'school'],
#  ['generic_name', 'team', 'participate', 'activities', 'school'],
#  ['advice', 'people', 'ask', 'multiple', 'opinions'],
#  ['advice', 'people', 'ask', 'multiple', 'opinions'],
#  ['phones', 'cell', 'phone', 'policy', 'school'],
#  ['face', 'mars', 'landform', 'aliens', 'natural'],
#  ['phones', 'cell', 'phone', 'policy', 'school'],
#  ['summer', 'project', 'projects', 'students', 'designed'],
#  ['face', 'mars', 'landform', 'aliens', 'natural'],
#  ['electoral', 'vote', 'college', 'president', 'electors'],
#  ['emotions', 'technology', 'facial', 'computer', 'could'],
#  ['face', 'mars', 'landform', 'aliens', 'natural'],
#  ['advice', 'people', 'ask', 'multiple', 'opinions'],
#  ['cars', 'driverless', 'car', 'driver', 'would'],
#  ['venus', 'planet', 'earth', 'author', 'surface'],
#  ['venus', 'planet', 'earth', 'author', 'surface'],
#  ['phones', 'cell', 'phone', 'policy', 'school'],
#  ['car', 'cars', 'usage', 'pollution', 'air'],
#  ['car', 'cars', 'usage', 'pollution', 'air'],
#  ['electoral', 'vote', 'college', 'president', 'electors'],
#  ['face', 'mars', 'landform', 'aliens', 'natural'],
#  ['generic_name', 'team', 'participate', 'activities', 'school'],
#  ['phones', 'cell', 'phone', 'policy', 'school'],
#  ['community', 'service', 'help', 'think', 'students'],
#  ['summer', 'project', 'projects', 'students', 'designed'],
#  ['generic_name', 'team', 'participate', 'activities', 'school'],
#  ['activities', 'school', 'students', 'extracurricular', 'sports'],
#  ['generic_name', 'team', 'participate', 'activities', 'school'],
#  ['community', 'service', 'help', 'think', 'students'],
#  ['summer', 'project', 'projects', 'students', 'designed'],
#  ['face', 'mars', 'landform', 'aliens', 'natural'],
#  ['electoral', 'vote', 'college', 'president', 'electors'],
#  ['phones', 'cell', 'phone', 'policy', 'school'],
#  ['phones', 'cell', 'phone', 'policy', 'school'],
#  ['venus', 'planet', 'earth', 'author', 'surface'],
#  ['students', 'online', 'school', 'classes', 'home'],
#  ['generic_name', 'team', 'participate', 'activities', 'school'],
#  ['electoral', 'vote', 'college', 'president', 'electors'],
#  ['emotions', 'technology', 'facial', 'computer', 'could'],
#  ['phones', 'cell', 'phone', 'policy', 'school'],
#  ['activities', 'school', 'students', 'extracurricular', 'sports'],
#  ['electoral', 'vote', 'college', 'president', 'electors'],
#  ['summer', 'project', 'projects', 'students', 'designed'],
#  ['electoral', 'vote', 'college', 'president', 'electors'],
#  ['car', 'cars', 'usage', 'pollution', 'air'],
#  ['venus', 'planet', 'earth', 'author', 'surface'],
#  ['advice', 'people', 'ask', 'multiple', 'opinions'],
#  ['community', 'service', 'help', 'think', 'students'],
#  ['face', 'mars', 'landform', 'aliens', 'natural'],
#  ['cars', 'driverless', 'car', 'driver', 'would'],
#  ['students', 'online', 'school', 'classes', 'home'],
#  ['car', 'cars', 'usage', 'pollution', 'air'],
#  ['driving', 'phone', 'phones', 'cell', 'texting'],
#  ['generic_name', 'team', 'participate', 'activities', 'school'],
#  ['students', 'online', 'school', 'classes', 'home'],
#  ['phones', 'cell', 'phone', 'policy', 'school'],
#  ['phones', 'cell', 'phone', 'policy', 'school'],
#  ['electoral', 'vote', 'college', 'president', 'electors'],
#  ['students', 'online', 'school', 'classes', 'home'],
#  ['emotions', 'technology', 'facial', 'computer', 'could'],
#  ['students', 'online', 'school', 'classes', 'home'],
#  ['advice', 'people', 'ask', 'multiple', 'opinions'],
#  ['driving', 'phone', 'phones', 'cell', 'texting'],
#  ['emotions', 'technology', 'facial', 'computer', 'could'],
#  ['car', 'cars', 'usage', 'pollution', 'air'],
#  ['car', 'cars', 'usage', 'pollution', 'air'],
#  ['car', 'cars', 'usage', 'pollution', 'air'],
#  ['activities', 'school', 'students', 'extracurricular', 'sports'],
#  ['activities', 'school', 'students', 'extracurricular', 'sports'],
#  ...]

# %%
with open("/content/drive/My Drive/Colab Notebooks/BERTopic_topic_list.txt","w") as text_file:
  text_file.write(topic_str)

# %%
import pandas as pd

for index, row in model.get_topic_info().iterrows():
  print(row.Representative_Docs)
# Out:
# ['Boom! Generic_Name kicks the soccer ball as hard as she can towards the goal. The goaly is surprised but quick on her feet as she thrusts herself towards the ball and catches it before it reaches the net. The referee blows the whistle and that is the end of the game. Generic_Name has not only let herself down, but her team as well. Each team shake hands with each other and leave the field. You have an expression on your face that describes disappointment and anger. Our school\'s principal, Generic_Name then looks at you from the bleachers and calls you over. As you make your way across the field, you keep yourself questioning yourself. What did I do? Am i going to be kicked off the team? Am I not good enough? Generic_Name asks you whether or not you think everybody at school should do at least one activity or sport. Generic_Name disagrees with this statement because students have after school activities they do that include sports, private lessons, and even classes.\n\nSports are a great way to exercise and distract yourself from school or even things that are stressful. There are different types of sports including football, soccer, baseball, basket
The car could accidently apply the gas instead of the breaks and then there would be a crash, or the wheel could turn right instead of left and you would be going the wrong way. That would make the driver frustrated and then they would end up taking over the car and driving themselves anyway.\n\nOr what if there is a crash, then who would be responsible for it.\n\nWould it be the driver of the driverless car or would it be the manufacturer who designed the car in the first place.\n\nThe car could have a malfunction and the driver of the car would be blamed even though they were not even driving the car.\n\nRight now the driverless cars are illegal in most states to even test them.\n\nSo if they are not tested properly, why would a driver want to risk his/her life when they could just drive themselves and they can guar ...
# ['The Facial Action Coding System is a new software that enables computers to identify human emotions. This software detects how other people are feeling even if they are trying to hide their emotions. Prof. Thomas Huang, of the Beckman Institute of Advanced Science at the University of Illinois, is the creator of this expectacular software. The use the Facial Action Coding System to read the emotional expressions of students in a classroom is helpful.\n\nThis computer software works with emotion algorithms. According to the passage, "The process begins when the computer constructs a 3-D computer model of the face; all 44 major muscles in the model must move like human muscles." Mona Lisa, Leonardo da Vinci\'s Renaissance painting, was tested with this software. A recent study shows that Mona Lisa is 83 percent happy, 9 percent disgusted, 6 percent fearful, 2 percent angry. The Facial Action Coding System uses video imagery, the new emotion-recognition software tracks these facial movements. The text also states that this software can even identify mixed emotions.\n\nThe Facial Action Coding System is helpful at schools. With the help of this software, teachers could know when a student is sad or angry. This computer software can also detect mixed emotions. This new software could even save lifes. For example, nowadays with the bullying\'s situation, a teacher would detect when a student is being bullyied or if the student is under a depression. The teacher could help him and prevent any type of accident. The software can help at schoosl in other ways. The text states, "\'A classroom computer could recognize when a student is becoming confused or bored,\' Dr. Hung predicts. \'Then it could modify the lesson, like an effective human instructor.\'"\n\nIn conclusion, the Facial Action Coding System has been developed that improves accuracy in perciving the emotions of others. Making faces reveal so much about the science of emotions. Becuase of this software, teachers could see when a student is sad or angry and the teacher could help him. The software could recognize when a student is becoming confused or bored. The use the Facial Action Coding System to read the emotion expressions of students in a classroom is helpful.', 'In the article "Making Mona Lisa Smile" by Nick D\'Alto, technology called the Facial Action Coding System enables computers to identify human emotions. The use of this technology should be used in schools to read the emotional expressions of students in a classroom because being able to identify what might be bothering others could be beneficial. Young adults could be facing something serious in their life but may not have the right words to express how they feel. Finding help for those feeling down is difficult. Using this technology could help those in need. This technology can help with identifying if a student is happy or worried, being able to have fun and put a smile on a students face while using this technology, and being able to identify if a student is confused or bored.\n\nThe Facial Action Coding System can help with students and their emotions. "Of course, most students would have trouble actually describing each facial trait that conveys happy, worried, etc." (5). Not everyone can tell what an individual is feeling. The help of this technology can help those who need it most. It can help detect if a student is happy or worried, but it can also put a smile on someones face.\n\nUsing this technology can help put a smile on your face in many ways. "The Mona Lisa demonstration is really intended to bring a smile to your face." (6). A lot of technology used today can put a smile on someone\'s face. Video games, social media, etc. Using the Facial Action Coding System is beneficial in many ways as well. It can help with being productive, getting help for a student who might need it. Technology can help with putting a smile on a students face, but it can also help with identifying if a student is conf ...
# ['Ever since cars were invented, they have widely been used as the primary source of transportation. They became so commonplace that their widespread use started to introduce negative impacts . As a result, some countries, or cities, have recently put in place programs or events to limit, or decrease, the amount of car usage in that area. There are many advantages to limiting car usage, including that not using cars is better for the environment and that it allows the city to improve itself.\n\nIn recent years, the environment has become a worldwide concern; one of the advantages to limiting car usage is that it will positively impact the environment. Today, people all over the world are paying attention to what they can do to help the environment, meaning that this is an advantage that will appeal to a widespread audience. One way that limiting car usage will help is that it will reduce greenhouse gas emissions. In Elisabeth Rosenthal\'s essay "In German Suburb, Life Goes On Without Cars", she writes, "Passenger cars are responsible for 2 percent of greenhouse gas emissions in Europe ... and up to 50 percent in some car-intensive areas in the United States". By limiting the usage of cars, the amount of greenhouse gases being emitted into the world would decrease substantially. While the idea that everyone would stop using their cars and the gas emissions caused by them would disappear completely is unrealistic, the prospect that a majority of the emissions could do so is perfectly reasonable. The reduction of these emissions would mean that the air quality would increase and be overall healthier for both all the world\'s population and all the wildlife across the world. Robert Duffer provides another example of how less car usage would impact the environment in his essay, "Paris bans driving due to smog". According to the article, an intense smog had covered Paris for five days, when the city decided to ban car usage over the course of two days. The cause for the smog was thought to be the high use of diesel fuel in France, with 67 percent of cars using it over gasoline, about 14 percent higher than the rest of Western Europe. The plan for the ban had been that cars with even-numbered license plates to not be used the first day and for ones with odd-numbered license plates not to be used the next day. In actuality, cars with odd-numbered plates were never banned from driving since the smog had cleared just after the first day. This shows the impact of limiting car usage. In just one day, a smog that was comarable to the one in Beijing, China, one of the most polluted cities in the world, was removed considerably after just half the normal amount of cars were used over the course of a day. If this was used all over the world, the result would be even more significant. This evidence supports that limiting car use is good for the environment in more ways than one.\n\nAdditionally, the limited use of cars opens many opportunities for cities to improve themselves by adding new features or improving upon old ones. In the article "Car-free day is spinning into a big hit in Bogota" by Andrew Selsky, the changes that the Columbian city of Bogota has gone through in response to less car use are discussed. The changes are a direct result of the city\'s Day Without Cars campaign, where car use is banned for the whole city for one day out of a year. It reads, "It has seen the construction of 118 mile of bicycle paths, the most of any Latin American city, according to Mockus, the city\'s mayor. Parks and sports centers have also bloomed throughout the city;uneven, pitted sidewalks have been replaced by broad, smooth sidewalks; rush-hour restrictions have dramatically cut traffic; and new restaurants and upscale shopping districts have cropped up".\xa0 These additions are in response to the city\'s inhabitants using alternative transport. Since cars could not be used, the public had to get to where they were heading by other means. Bogota w ...
# ['Venus is the closest planet to Earth. The planet Venus is known as Earth\'s twin because its the close to earth density and size, and is also sometimes called the "Evening Star," In the article "The Challenge of Exploring Venus." The author claims that studying Venus is a worthy pursuit despite the dangers. The aurthour says in paragraph 4 that Venus can be our nearest option for a planetary vist. The author also says that Long ago, Venus was probably covered largely with oceans and could have many forms of like, like Earth. The author also says in paragraph 8 that our travels on Earth and beyond should not be limited by dangers and doubts, but should be expanded to meet the very edges of imagination and innovation.\n\nI think that we should not waste our time to explore Venus. Even though the planet is somewhat identical to Earth, the planet is very chaotic and dangerous. In paragraph 3, the author tells the readers the many dangers of Venus. The planet is covered in a thick atmosphere of about 97 carbon dioxide, and the atmosphere has clouds of highly corrosive sulfuric acid. The planet\'s surface temperatures average over 800 degrees Fahrenheit. Also, the atmospheric pressure is 90 times greater than what Earth is. Venus also has the hottest
of students actually completing a teacher-based project efficiently\xa0is slim as well. But, if it was a student-designed project, the completion rate would skyrocket due to the fact the students would actually want to do the summer work. It will be hard for students to motivate and push themselves to complete a project if it is boring. Teacher-design summer work would be unfair to students that would like to control their education and topic. Projects and assignments based on the students interest would exemplify\xa0better work ethic and dedication. It is important for students to continue learning during the summer, but it should be learning based on their interests and goals\xa0rather than any teacher.\n\nIt would not be a good decision to let students design and control their own summer projects or assignments because it is important students are learning the correct material necessary for class. It would be pointless for students to complete a summer assignment or project if it was not based on the school's curriculum. A teacher-designed project would be more beneficial for the students than allowing the students to design their own project, The instructors are aware of the things the students will be required to learn during the  ...
# ["Dear Principal,\n\nI believe that policy 1 is the best policy to enforce about cell phones. This policy will allow us to contact our parents or friends if needed. The use of cell phones in class is wrong but having them during lunch will not cause disruptions. Cell phones can be an annoyance during class but having them when not in class is perfectly acceptable.\n\nCell phones are disruptive to teachers and other students during class. If a phone goes off while others are trying to learn it interrupts their attention and annoys the teacher. However having cell phones during lunch or free periods would not disrupt any learning because you are not in a classroom. As long as cell phones are turned off and not being used during class time I see no reason why students should not be allowed to have them.\n\nIf a student gets sick or needs something having a cell phone with them can let them call home to contact someone. Even though they can call from the office having a cell phone on hand is a quicker and easier way to contact somebody. Also if a student has some kind of after school practice and can't have their phone with them at school then they won't be able to let their parent know if practice is running late or will finish early. Cell phones are necessary for students to have.\n\nPolicy 2 states that students can not have phones at school at all. If you choose policy 2 then students will still bring their phones and use them even more. Teenagers do what they are told not to do. If you tell us we can't have our phones that will just make us want to have them more. Policy 2 will just create more cell phone usage at school and more disruptions to the learning environment.\n\nAs you can see I believe that policy 1 is the best policy to enforce at this school. It will let students have their phones outside of class and they can have them if they need to contact some one. Even though cell phones are a nuisance to class this policy only lets you have them when you are not in class. Cell phones are necessary for contacting a parent or just for texting a friend. This is why policy 1 is the best policy for our school.\n\nSincerely,\n\nSTUDENT_NAME", "Dear TEACHER_NAME,\n\nI understand that you are considering two possible policies that have to do with using cell phones in school. I think that you should think of allowing students to bring phones to school and let them use them during lunch periods and other free times, as long as the phones are turned off during class time. thirty percent of the population of children are getting in trouble in school because of the use of cell phones in school.\n\nFirst of all, if students have cell phones then they will be tempted to use it and might get in trouble if they use it in class secretly because they are not allowed to use them in school. Lets say that students are in class and they feel the urge to text because they have not used the phone that day. They will want to use it in class but they will do it secretly so the teacher wont take it away. For example there was this kid in my class and while we were in the middle of the lesson he would take out the phone while the teacher had her back to us and start using it. If you put the policy that will let us use our cell phones in school during lunch periods and free time then we will have enough texting done so that we will not need to text anymore until school is finished or until their next free time.\n\nSecond of all, if we were able to use our phones in lunch periods or free times then what will be the point of students getting in trouble all the time because of cell phones. Just think about it, if students aren't able to use their phones in school at all then they will use it no matter what the case is because they feel the urge to do it. They will feel the need to do it because either they receive text that will make them want to reply back or they become so obsessed with using them that they think that they have to use it.\n\nLastly, yo ...
# ['The Landform that Looks like a Face\n\nOn Earth, there are many landforms that might look like a person or a thing. On Mars, there is a landform that looks like a face. This Face has had several photos of it taken by Viking 1 in 1976, a Mars Global surveyor (MGS) in 1998, and another (MGS) in 2001. The Face looks like a face because of its characteristics. Although it looks like an enourmous head, it is really just a mesa or butte, a landform, that happens to look like a face.\n\nOne reason that this landform is not a face is because NASA revealed a close up picture of the face, revealing only a landform. That picture had a caption that stated, "huge rock formation... which resembles a human head... formed by shadows giving the illusion of eyes, nose, and mouth." Before, there were pictures that weren\'t as high resolution, so it looked like a face but is now proven to be just a landform. This shows that the landform that looks like a face, is just a landform since there is a photo that shows what the "face" actually is. This means the face is just a mesa or butte.\n\nAnother reason why this Face is just a natural landform, is because this landform is in Cydonia where mesas are common. The text states, "Scientists figured it was just another Martian mesa, common enough around Cydonia, only this one had unusual shadows that made it look like an egyptian pharoah." This shows that mesas in Cydonia are common. Also, the mesa just had unusual shadows that gave it the appearence of a face. This means that this face was just a landform.\n\nAnother reason, is that some landforms, like on Earth look like something other than a landform. The text states, "\'It reminds me most of Middle Butte in the Snake River Plain of Idaho.\', says Garvin." This shows that some landforms can represent or look different from what it really is. This would be the Face oon Mars that is a landform. This wouldn\'t be a face.\n\nThough some people, like cospiracy theorists, may say that NASA wants to hide a type of evidence for life on Mars, they are wrong. The text states,"Some people think the Face is bona fide evidence for life on Mars- evidence that NASA would rather hide, say cospiracy theorists." The text also states, "Meanwhile, defenders of the NASA budget wish there was an ancient civilization on Mars." NASA responds to conspiracy theorist in this way, because if NASA were to be responsible for discovering life on Mars, they would benefit. This shows that though NASA would like to be responsible fo discovering life on Mars, NASA just wanted to prove that this Face is just a natural landform.\n\nOverall, there are several reasons why this Face is just a natural landform. One of them is that NASA took a picture of the Face, revealing just a landform. Another reason, is that mesas are common in Cydonia, the area where the Face was found. Another reason, is that thhis landfprm like others can look different from what it really is. In conclusion, the Face on Mars is just a landform.', 'The Face on Mars is not made by aliens. There is no proof whatsoever of any signs of life on Mars, which means no aliens. The face on Mars is just a natural landform that coincidently looks like a human face. Given the shadows and shape, the Face very much looks like it has a human nose mouth, and eyes. Although up close, there is no resemblence of a human face. Therefore, do not let this anyone fool you.\n\nPictures have been taken by NASA of the Face to prove it is just a natural landform. Pictures taken from 1976 appear blurry, and not clear, so it is easy to believe that aliens created the Face. Although, in 1998, the pictures taken aren\'t as blurry, and you can see the structure of the landfrom clearly. Lastly, the picture taken in 2001 is clear and visible. You can perfectly see that close up, the Face is just another natural landform on Mars. From far away, it looks like a human face because of the shadows, but up close, it is nothing more than a simple landform. ...
# ["Dear Principal,\n\nHelping out the community is always a good thing to do.\n\nSome people like helping, but others don't. I understand that people are busy with other things and might not have time to help the community, but little things you do help.\n\nTherefore, i think that the students should perform community service.\n\nIf you have something else going on like sports for example, you could take a day off from them to help the community. Some people don't even play sports because they can't afford it, so think how they feel. If the students helped out the community, i think the community would appreciate it, and be thankful that the kids took time out of their schedule to help them.\n\nCommunity service doesn't take long, the longest it would take is a day. After you do community service you feel good because you know you helped people.\n\nEven if theirs certain things you don't like doing for community service, there's many things that you could choose from.\n\nI know i would feel good if people helped me out, and the people you are helping will feel good too. As a principal you should encourage the kids to do community service